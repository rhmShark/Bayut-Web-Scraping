# %%
#q8mjF5vUm2FgVwyE
#newrm

# %%
#!pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pymongo
#   Downloading pymongo-4.12.1-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.12.1-cp311-cp311-win_amd64.whl (847 kB)
#    ---------------------------------------- 0.0/847.1 kB ? eta -:--:--
#    --- ------------------------------------ 81.9/847.1 kB 2.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 225.3/847.1 kB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 409.6/847.1 kB 3.2 MB/s eta 0:00:01
#    --------------------------- ------------ 583.7/847.1 kB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 778.2/847.1 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 847.1/847.1 kB 3.3 MB/s eta 0:00:00
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.12.1

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://newrm:q8mjF5vUm2FgVwyE@ramindata.6h2kwxj.mongodb.net/?retryWrites=true&w=majority&appName=RamInData"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/rahma/Desktop/alexandria_properties.csv")
df
# Out:
#                  Ref. No                                              title  \
# 0   Bayut - 11444-YixQR7        Luxury apartment for sale in Compound Muruj
# 1   Bayut - 11444-YixQR7        Luxury apartment for sale in Compound Muruj
# 2          Bayut - Mi097  Prime location in the heart of Smouha in front...
# 3          Bayut - Mi097  Prime location in the heart of Smouha in front...
# 4          Bayut - Mi095  Apartment Book a wonderful apartment, third fl...
# ..                   ...                                                ...
# 91     Bayut - PSR002P52  Own a corner apartment in Sawary with a fully ...
# 92      Bayut - MD004343  Own your apartment on the club floor at the ol...
# 93      Bayut - MD004343  Own your apartment on the club floor at the ol...
# 94      Bayut - ME004343   Own your unit on the club in the heart of Smouha
# 95      Bayut - ME004343   Own your unit on the club in the heart of Smouha
#
#          type      price bedrooms bathrooms        area
# 0   Apartment  3,700,000   2 Beds   3 Baths  127 Sq. M.
# 1   Apartment  3,700,000   2 Beds   3 Baths  127 Sq. M.
# 2   Apartment  9,700,000   3 Beds   2 Baths  204 Sq. M.
# 3   Apartment  9,700,000   3 Beds   2 Baths  204 Sq. M.
# 4   Apartment  7,771,700   3 Beds   2 Baths  155 Sq. M.
# ..        ...        ...      ...       ...         ...
# 91  Apartment  8,500,000   3 Beds   3 Baths  170 Sq. M.
# 92  Apartment  6,500,000   3 Beds   2 Baths  160 Sq. M.
# 93  Apartment  6,500,000   3 Beds   2 Baths  160 Sq. M.
# 94  Apartment  6,500,000   3 Beds   2 Baths  160 Sq. M.
# 95  Apartment  6,500,000   3 Beds   2 Baths  160 Sq. M.
#
# [96 rows x 7 columns]

# %%
# inserting in mogodb
list_of_dict = df.to_dict(orient='records')

# %%
# Out:
# [{'Ref. No': 'Bayut - 11444-YixQR7',
#   'title': 'Luxury apartment for sale in Compound Muruj',
#   'type': 'Apartment',
#   'price': '3,700,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '3 Baths',
#   'area': '127 Sq. M.'},
#  {'Ref. No': 'Bayut - 11444-YixQR7',
#   'title': 'Luxury apartment for sale in Compound Muruj',
#   'type': 'Apartment',
#   'price': '3,700,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '3 Baths',
#   'area': '127 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi097',
#   'title': 'Prime location in the heart of Smouha in front of Green Plaza, overlooking the club and the plaza, 204-square-meter apartment, ultra-luxurious finishi',
#   'type': 'Apartment',
#   'price': '9,700,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '204 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi097',
#   'title': 'Prime location in the heart of Smouha in front of Green Plaza, overlooking the club and the plaza, 204-square-meter apartment, ultra-luxurious finishi',
#   'type': 'Apartment',
#   'price': '9,700,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '204 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi095',
#   'title': 'Apartment Book a wonderful apartment, third floor, 3 rooms, area 155 square meters, in the most upscale residential compound with integrated services.',
#   'type': 'Apartment',
#   'price': '7,771,700',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '155 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi095',
#   'title': 'Apartment Book a wonderful apartment, third floor, 3 rooms, area 155 square meters, in the most upscale residential compound with integrated services.',
#   'type': 'Apartment',
#   'price': '7,771,700',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '155 Sq. M.'},
#  {'Ref. No': 'Bayut - 11444-TmZn9D',
#   'title': 'luxury apartment for sale in Compound Muruj 147 m   (Plaza view  width 47m )',
#   'type': 'Apartment',
#   'price': '8,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '147 Sq. M.'},
#  {'Ref. No': 'Bayut - 11444-TmZn9D',
#   'title': 'luxury apartment for sale in Compound Muruj 147 m   (Plaza view  width 47m )',
#   'type': 'Apartment',
#   'price': '8,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '147 Sq. M.'},
#  {'Ref. No': 'Bayut - 11444-UPlvlM',
#   'title': 'Luxury apartment for sale in Compound Muruj',
#   'type': 'Apartment',
#   'price': '7,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '211 Sq. M.'},
#  {'Ref. No': 'Bayut - 11444-UPlvlM',
#   'title': 'Luxury apartment for sale in Compound Muruj',
#   'type': 'Apartment',
#   'price': '7,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '211 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi093',
#   'title': 'In the heart of Smouha, an apartment in a fully serviced compound, 187 square meters, ultra-luxury finishing, with a down payment of 600 thousand and',
#   'type': 'Apartment',
#   'price': '11,143,330',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '187 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi093',
#   'title': 'In the heart of Smouha, an apartment in a fully serviced compound, 187 square meters, ultra-luxury finishing, with a down payment of 600 thousand and',
#   'type': 'Apartment',
#   'price': '11,143,330',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '187 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi092',
#   'title': 'Valori Smouha, Transport and Engineering Street, available, 177 sqm apartment, ultra-luxurious finishing, 3 bedrooms + 3 bathrooms + reception. The ne',
#   'type': 'Apartment',
#   'price': '7,965,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '177 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi092',
#   'title': 'Valori Smouha, Transport and Engineering Street, available, 177 sqm apartment, ultra-luxurious finishing, 3 bedrooms + 3 bathrooms + reception. The ne',
#   'type': 'Apartment',
#   'price': '7,965,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '177 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi091',
#   'title': 'Residential or investment opportunity: A wonderful apartment on the fourth floor in Palm Hills Alexandria, to be delivered in 6 months, 147 square met',
#   'type': 'Apartment',
#   'price': '14,735,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '3 Baths',
#   'area': '147 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi091',
#   'title': 'Residential or investment opportunity: A wonderful apartment on the fourth floor in Palm Hills Alexandria, to be delivered in 6 months, 147 square met',
#   'type': 'Apartment',
#   'price': '14,735,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '3 Baths',
#   'area': '147 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi062',
#   'title': 'Valori Antaniados Compound on the Martyrs Axis consists of 20 towers with different views, a commercial area for the compound, a gym, a kids area, and',
#   'type': 'Apartment',
#   'price': '7,335,200',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '218 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi062',
#   'title': 'Valori Antaniados Compound on the Martyrs Axis consists of 20 towers with different views, a commercial area for the compound, a gym, a kids area, and',
#   'type': 'Apartment',
#   'price': '7,335,200',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '218 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi061',
#   'title': 'Sawary Carrefour City Center Alexandria neighborhood, available apartment 148 square meters, second floor, ultra-luxurious finishing, 3 bedrooms + 2 b',
#   'type': 'Apartment',
#   'price': '8,660,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '148 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi061',
#   'title': 'Sawary Carrefour City Center Alexandria neighborhood, available apartment 148 square meters, second floor, ultra-luxurious finishing, 3 bedrooms + 2 b',
#   'type': 'Apartment',
#   'price': '8,660,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '148 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi060',
#   'title': 'Prime location in the heart of Smouha in front of Green Plaza, overlooking the club and the plaza, 131-square-meter apartment, ultra-luxurious finishi',
#   'type': 'Apartment',
#   'price': '6,353,500',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '131 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi060',
#   'title': 'Prime location in the heart of Smouha in front of Green Plaza, overlooking the club and the plaza, 131-square-meter apartment, ultra-luxurious finishi',
#   'type': 'Apartment',
#   'price': '6,353,500',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '131 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi055',
#   'title': 'For lovers of upscale areas, Smouha, a 145-square-meter apartment is available on the fifth floor, with two elevators, ultra-luxurious finishing, and',
#   'type': 'Apartment',
#   'price': '5,400,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '1 Bath',
#   'area': '145 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi055',
#   'title': 'For lovers of upscale areas, Smouha, a 145-square-meter apartment is available on the fifth floor, with two elevators, ultra-luxurious finishing, and',
#   'type': 'Apartment',
#   'price': '5,400,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '1 Bath',
#   'area': '145 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi052',
#   'title': 'A seat is available on Fawzy Moaz Street, Smouha, 149 square meters, 7th floor, buildings 2008, 24-horse security guard, fully metered, licensed, supe',
#   'type': 'Apartment',
#   'price': '4,600,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '1 Bath',
#   'area': '149 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi052',
#   'title': 'A seat is available on Fawzy Moaz Street, Smouha, 149 square meters, 7th floor, buildings 2008, 24-horse security guard, fully metered, licensed, supe',
#   'type': 'Apartment',
#   'price': '4,600,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '1 Bath',
#   'area': '149 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi051',
#   'title': 'Book the best apartment in Alex West, 153 square meters, on the largest plaza, with a delivery period of two years, and a very open view. An opportuni',
#   'type': 'Apartment',
#   'price': '8,023,320',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '153 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi051',
#   'title': 'Book the best apartment in Alex West, 153 square meters, on the largest plaza, with a delivery period of two years, and a very open view. An opportuni',
#   'type': 'Apartment',
#   'price': '8,023,320',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '153 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi050',
#   'title': 'Book the best apartment in Alex West, 178 square meters, on the largest plaza, with a delivery period of two years, and a very open view. An opportuni',
#   'type': 'Apartment',
#   'price': '9,416,200',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '178 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi050',
#   'title': 'Book the best apartment in Alex West, 178 square meters, on the largest plaza, with a delivery period of two years, and a very open view. An opportuni',
#   'type': 'Apartment',
#   'price': '9,416,200',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '178 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi041',
#   'title': 'With the lowest down payment and the longest payment period, Palm Hills Alexandria, two minutes from Carrefour City Center Alexandria, with installmen',
#   'type': 'Apartment',
#   'price': '10,721,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '2 Baths',
#   'area': '119 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi041',
#   'title': 'With the lowest down payment and the longest payment period, Palm Hills Alexandria, two minutes from Carrefour City Center Alexandria, with installmen',
#   'type': 'Apartment',
#   'price': '10,721,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '2 Baths',
#   'area': '119 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi056',
#   'title': 'Sawary neighborhood, Carrefour City Center, Alexandria. A 7th floor apartment is available, ultra-luxurious finishing, 3 bedrooms + 3 bathrooms + rece',
#   'type': 'Apartment',
#   'price': '9,189,600',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '202 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi056',
#   'title': 'Sawary neighborhood, Carrefour City Center, Alexandria. A 7th floor apartment is available, ultra-luxurious finishing, 3 bedrooms + 3 bathrooms + rece',
#   'type': 'Apartment',
#   'price': '9,189,600',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '202 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi038',
#   'title': 'With a 10% down payment, a 165-square-meter apartment is available in Marouj Smouha Compound, sixth floor, ultra-luxurious finishing, facilities over',
#   'type': 'Apartment',
#   'price': '9,900,000',
#   'bedrooms': '4 Beds',
#   'bathrooms': '2 Baths',
#   'area': '165 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi038',
#   'title': 'With a 10% down payment, a 165-square-meter apartment is available in Marouj Smouha Compound, sixth floor, ultra-luxurious finishing, facilities over',
#   'type': 'Apartment',
#   'price': '9,900,000',
#   'bedrooms': '4 Beds',
#   'bathrooms': '2 Baths',
#   'area': '165 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi040',
#   'title': 'Sawary neighborhood, Carrefour City Center, Alexandria. Apartment available, 133 square meters, 3rd floor, ultra-luxurious finishing, 2 bedrooms + 2 b',
#   'type': 'Apartment',
#   'price': '5,500,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '2 Baths',
#   'area': '133 Sq. M.'},
#  {'Ref. No': 'Bayut - Mi040',
#   'title': 'Sawary neighborhood, Carrefour City Center, Alexandria. Apartment available, 133 square meters, 3rd floor, ultra-luxurious finishing, 2 bedrooms + 2 b',
#   'type': 'Apartment',
#   'price': '5,500,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '2 Baths',
#   'area': '133 Sq. M.'},
#  {'Ref. No': 'Bayut - 5000709-iczvgC',
#   'title': 'Sporting Luxor Street',
#   'type': 'Apartment',
#   'price': '4,350,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '125 Sq. M.'},
#  {'Ref. No': 'Bayut - 5000709-iczvgC',
#   'title': 'Sporting Luxor Street',
#   'type': 'Apartment',
#   'price': '4,350,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '125 Sq. M.'},
#  {'Ref. No': 'Bayut - 70060105',
#   'title': 'Resale unit for sale in Sawary - Egyptian Saudi Arabia',
#   'type': 'Apartment',
#   'price': '7,800,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '177 Sq. M.'},
#  {'Ref. No': 'Bayut - 70060105',
#   'title': 'Resale unit for sale in Sawary - Egyptian Saudi Arabia',
#   'type': 'Apartment',
#   'price': '7,800,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '177 Sq. M.'},
#  {'Ref. No': 'Bayut - 128482',
#   'title': 'Apartment for sale, 155 m, Alex West Compound (Down payment: EGP 377,000 - Delivery in one year)',
#   'type': 'Apartment',
#   'price': '7,557,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '155 Sq. M.'},
#  {'Ref. No': 'Bayut - 128482',
#   'title': 'Apartment for sale, 155 m, Alex West Compound (Down payment: EGP 377,000 - Delivery in one year)',
#   'type': 'Apartment',
#   'price': '7,557,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '155 Sq. M.'},
#  {'Ref. No': 'Bayut - 128460',
#   'title': 'Apartment for sale, 140m, Smouha - Marouj Compound (Open view on 40m street - Seafront)',
#   'type': 'Apartment',
#   'price': '6,417,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '140 Sq. M.'},
#  {'Ref. No': 'Bayut - 128460',
#   'title': 'Apartment for sale, 140m, Smouha - Marouj Compound (Open view on 40m street - Seafront)',
#   'type': 'Apartment',
#   'price': '6,417,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '140 Sq. M.'},
#  {'Ref. No': 'Bayut - 004371',
#   'title': 'Apartment for sale 100m Sidi Bishr (Steps from Al-Eisawi)',
#   'type': 'Apartment',
#   'price': '2,200,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '1 Bath',
#   'area': '100 Sq. M.'},
#  {'Ref. No': 'Bayut - 004371',
#   'title': 'Apartment for sale 100m Sidi Bishr (Steps from Al-Eisawi)',
#   'type': 'Apartment',
#   'price': '2,200,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '1 Bath',
#   'area': '100 Sq. M.'},
#  {'Ref. No': 'Bayut - 128472',
#   'title': 'Apartment for sale, 233 m², Palm Hills Alexandria Compound (sea view)',
#   'type': 'Apartment',
#   'price': '16,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '233 Sq. M.'},
#  {'Ref. No': 'Bayut - 128472',
#   'title': 'Apartment for sale, 233 m², Palm Hills Alexandria Compound (sea view)',
#   'type': 'Apartment',
#   'price': '16,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '233 Sq. M.'},
#  {'Ref. No': 'Bayut - 127892',
#   'title': 'Apartment for sale, 177 m, Sawary Egyptian Saudi Compound (direct club view)',
#   'type': 'Apartment',
#   'price': '8,300,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '177 Sq. M.'},
#  {'Ref. No': 'Bayut - 127892',
#   'title': 'Apartment for sale, 177 m, Sawary Egyptian Saudi Compound (direct club view)',
#   'type': 'Apartment',
#   'price': '8,300,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '177 Sq. M.'},
#  {'Ref. No': 'Bayut - 128508',
#   'title': 'Apartment for sale, 290 m², Rushdy - El Moaskar Street',
#   'type': 'Apartment',
#   'price': '14,000,000',
#   'bedrooms': '4 Beds',
#   'bathrooms': '3 Baths',
#   'area': '290 Sq. M.'},
#  {'Ref. No': 'Bayut - 128508',
#   'title': 'Apartment for sale, 290 m², Rushdy - El Moaskar Street',
#   'type': 'Apartment',
#   'price': '14,000,000',
#   'bedrooms': '4 Beds',
#   'bathrooms': '3 Baths',
#   'area': '290 Sq. M.'},
#  {'Ref. No': 'Bayut - 128502',
#   'title': 'Apartment for sale 205m Smouha - Valori Compound',
#   'type': 'Apartment',
#   'price': '7,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '205 Sq. M.'},
#  {'Ref. No': 'Bayut - 128502',
#   'title': 'Apartment for sale 205m Smouha - Valori Compound',
#   'type': 'Apartment',
#   'price': '7,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '205 Sq. M.'},
#  {'Ref. No': 'Bayut - 301795',
#   'title': 'Apartment for sale, 125 m², Sporting (Abu Qir Street)',
#   'type': 'Apartment',
#   'price': '4,200,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '125 Sq. M.'},
#  {'Ref. No': 'Bayut - 301795',
#   'title': 'Apartment for sale, 125 m², Sporting (Abu Qir Street)',
#   'type': 'Apartment',
#   'price': '4,200,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '125 Sq. M.'},
#  {'Ref. No': 'Bayut - PW004P52',
#   'title': 'Own your unit with a monthly installment of 35,000 in Alex West with an open view of the largest plaza',
#   'type': 'Apartment',
#   'price': '7,009,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '178 Sq. M.'},
#  {'Ref. No': 'Bayut - PW004P52',
#   'title': 'Own your unit with a monthly installment of 35,000 in Alex West with an open view of the largest plaza',
#   'type': 'Apartment',
#   'price': '7,009,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '178 Sq. M.'},
#  {'Ref. No': 'Bayut - 029073',
#   'title': 'Apartment for sale 161 m in Suwari (Green Business Hub)',
#   'type': 'Apartment',
#   'price': '6,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '161 Sq. M.'},
#  {'Ref. No': 'Bayut - 029073',
#   'title': 'Apartment for sale 161 m in Suwari (Green Business Hub)',
#   'type': 'Apartment',
#   'price': '6,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '161 Sq. M.'},
#  {'Ref. No': 'Bayut - 004334',
#   'title': 'Own your apartment with open lake views in Marouj Smouha',
#   'type': 'Apartment',
#   'price': '9,850,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '168 Sq. M.'},
#  {'Ref. No': 'Bayut - 004334',
#   'title': 'Own your apartment with open lake views in Marouj Smouha',
#   'type': 'Apartment',
#   'price': '9,850,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '168 Sq. M.'},
#  {'Ref. No': 'Bayut - 128475',
#   'title': 'Apartment for sale 141m Smouha - Muruj Compound',
#   'type': 'Apartment',
#   'price': '7,986,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '141 Sq. M.'},
#  {'Ref. No': 'Bayut - 128475',
#   'title': 'Apartment for sale 141m Smouha - Muruj Compound',
#   'type': 'Apartment',
#   'price': '7,986,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '141 Sq. M.'},
#  {'Ref. No': 'Bayut - 128463',
#   'title': 'Apartment for sale, 175 m², Louran - Direct sea view',
#   'type': 'Apartment',
#   'price': '5,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '175 Sq. M.'},
#  {'Ref. No': 'Bayut - 128463',
#   'title': 'Apartment for sale, 175 m², Louran - Direct sea view',
#   'type': 'Apartment',
#   'price': '5,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '175 Sq. M.'},
#  {'Ref. No': 'Bayut - 128488',
#   'title': 'Apartment for sale, 155 m, Alex West Compound (Down Payment: EGP 363,630)',
#   'type': 'Apartment',
#   'price': '7,272,600',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '155 Sq. M.'},
#  {'Ref. No': 'Bayut - 128488',
#   'title': 'Apartment for sale, 155 m, Alex West Compound (Down Payment: EGP 363,630)',
#   'type': 'Apartment',
#   'price': '7,272,600',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '155 Sq. M.'},
#  {'Ref. No': 'Bayut - 128524',
#   'title': 'Resale apartment for sale, 120 m², Smouha - Marouj Compound (Price per meter: 31,000 EGP)',
#   'type': 'Apartment',
#   'price': '3,800,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '2 Baths',
#   'area': '120 Sq. M.'},
#  {'Ref. No': 'Bayut - 128524',
#   'title': 'Resale apartment for sale, 120 m², Smouha - Marouj Compound (Price per meter: 31,000 EGP)',
#   'type': 'Apartment',
#   'price': '3,800,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '2 Baths',
#   'area': '120 Sq. M.'},
#  {'Ref. No': 'Bayut - A5',
#   'title': 'The apartment is located in the Miami area, third street from Al-Eisawi',
#   'type': 'Apartment',
#   'price': '3,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '1 Bath',
#   'area': '135 Sq. M.'},
#  {'Ref. No': 'Bayut - A5',
#   'title': 'The apartment is located in the Miami area, third street from Al-Eisawi',
#   'type': 'Apartment',
#   'price': '3,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '1 Bath',
#   'area': '135 Sq. M.'},
#  {'Ref. No': 'Bayut - 128456',
#   'title': 'Apartment for sale 145m Smouha - Muruj Compound',
#   'type': 'Apartment',
#   'price': '7,032,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '145 Sq. M.'},
#  {'Ref. No': 'Bayut - 128456',
#   'title': 'Apartment for sale 145m Smouha - Muruj Compound',
#   'type': 'Apartment',
#   'price': '7,032,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '145 Sq. M.'},
#  {'Ref. No': 'Bayut - .. PW015P52',
#   'title': 'Own your apartment in the largest plaza in Alex West',
#   'type': 'Apartment',
#   'price': '8,023,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '153 Sq. M.'},
#  {'Ref. No': 'Bayut - .. PW015P52',
#   'title': 'Own your apartment in the largest plaza in Alex West',
#   'type': 'Apartment',
#   'price': '8,023,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '153 Sq. M.'},
#  {'Ref. No': 'Bayut - 128457',
#   'title': 'Apartment for sale 150m Smouha - Muruj Compound',
#   'type': 'Apartment',
#   'price': '7,050,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '150 Sq. M.'},
#  {'Ref. No': 'Bayut - 128457',
#   'title': 'Apartment for sale 150m Smouha - Muruj Compound',
#   'type': 'Apartment',
#   'price': '7,050,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '150 Sq. M.'},
#  {'Ref. No': 'Bayut - A2',
#   'title': 'A unique opportunity to own an apartment in a prime location in San Stefano, ready for immediate occupancy.',
#   'type': 'Apartment',
#   'price': '3,500,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '1 Bath',
#   'area': '135 Sq. M.'},
#  {'Ref. No': 'Bayut - A2',
#   'title': 'A unique opportunity to own an apartment in a prime location in San Stefano, ready for immediate occupancy.',
#   'type': 'Apartment',
#   'price': '3,500,000',
#   'bedrooms': '2 Beds',
#   'bathrooms': '1 Bath',
#   'area': '135 Sq. M.'},
#  {'Ref. No': 'Bayut - A1',
#   'title': 'Apartment for sale in Grand Plaza Compound - El Seyouf Shamaa, prime location',
#   'type': 'Apartment',
#   'price': '3,300,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '150 Sq. M.'},
#  {'Ref. No': 'Bayut - A1',
#   'title': 'Apartment for sale in Grand Plaza Compound - El Seyouf Shamaa, prime location',
#   'type': 'Apartment',
#   'price': '3,300,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '150 Sq. M.'},
#  {'Ref. No': 'Bayut - 128481',
#   'title': 'Apartment for sale, 153 m², Alex West Compound (fully open landscape view)',
#   'type': 'Apartment',
#   'price': '4,896,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '153 Sq. M.'},
#  {'Ref. No': 'Bayut - 128481',
#   'title': 'Apartment for sale, 153 m², Alex West Compound (fully open landscape view)',
#   'type': 'Apartment',
#   'price': '4,896,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '153 Sq. M.'},
#  {'Ref. No': 'Bayut - 001022',
#   'title': 'Apartment for sale 125m Fleming (Ahmed Pasha Turk St. - Steps from Mostafa Kamel Main St. )',
#   'type': 'Apartment',
#   'price': '2,650,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '1 Bath',
#   'area': '125 Sq. M.'},
#  {'Ref. No': 'Bayut - 001022',
#   'title': 'Apartment for sale 125m Fleming (Ahmed Pasha Turk St. - Steps from Mostafa Kamel Main St. )',
#   'type': 'Apartment',
#   'price': '2,650,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '1 Bath',
#   'area': '125 Sq. M.'},
#  {'Ref. No': 'Bayut - A3',
#   'title': 'Apartment for sale in Moharram Bek - prime location next to Fathallah!',
#   'type': 'Apartment',
#   'price': '5,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '150 Sq. M.'},
#  {'Ref. No': 'Bayut - A3',
#   'title': 'Apartment for sale in Moharram Bek - prime location next to Fathallah!',
#   'type': 'Apartment',
#   'price': '5,000,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '150 Sq. M.'},
#  {'Ref. No': 'Bayut - PSR002P52',
#   'title': 'Own a corner apartment in Sawary with a fully open landscape view',
#   'type': 'Apartment',
#   'price': '8,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '170 Sq. M.'},
#  {'Ref. No': 'Bayut - PSR002P52',
#   'title': 'Own a corner apartment in Sawary with a fully open landscape view',
#   'type': 'Apartment',
#   'price': '8,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '3 Baths',
#   'area': '170 Sq. M.'},
#  {'Ref. No': 'Bayut - MD004343',
#   'title': 'Own your apartment on the club floor at the old price in Marouj',
#   'type': 'Apartment',
#   'price': '6,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '160 Sq. M.'},
#  {'Ref. No': 'Bayut - MD004343',
#   'title': 'Own your apartment on the club floor at the old price in Marouj',
#   'type': 'Apartment',
#   'price': '6,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '160 Sq. M.'},
#  {'Ref. No': 'Bayut - ME004343',
#   'title': 'Own your unit on the club in the heart of Smouha',
#   'type': 'Apartment',
#   'price': '6,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '160 Sq. M.'},
#  {'Ref. No': 'Bayut - ME004343',
#   'title': 'Own your unit on the club in the heart of Smouha',
#   'type': 'Apartment',
#   'price': '6,500,000',
#   'bedrooms': '3 Beds',
#   'bathrooms': '2 Baths',
#   'area': '160 Sq. M.'}]

# %%
db = client["mydata"]

# %%
db.list_collection_names()
# Out:
# ['RamInData']

# %%
collection = db.create_collection("property")

# %%
collection.insert_many(list_of_dict)
# Out:
# InsertManyResult([ObjectId('68152a49d7982aac2b8fa1bb'), ObjectId('68152a49d7982aac2b8fa1bc'), ObjectId('68152a49d7982aac2b8fa1bd'), ObjectId('68152a49d7982aac2b8fa1be'), ObjectId('68152a49d7982aac2b8fa1bf'), ObjectId('68152a49d7982aac2b8fa1c0'), ObjectId('68152a49d7982aac2b8fa1c1'), ObjectId('68152a49d7982aac2b8fa1c2'), ObjectId('68152a49d7982aac2b8fa1c3'), ObjectId('68152a49d7982aac2b8fa1c4'), ObjectId('68152a49d7982aac2b8fa1c5'), ObjectId('68152a49d7982aac2b8fa1c6'), ObjectId('68152a49d7982aac2b8fa1c7'), ObjectId('68152a49d7982aac2b8fa1c8'), ObjectId('68152a49d7982aac2b8fa1c9'), ObjectId('68152a49d7982aac2b8fa1ca'), ObjectId('68152a49d7982aac2b8fa1cb'), ObjectId('68152a49d7982aac2b8fa1cc'), ObjectId('68152a49d7982aac2b8fa1cd'), ObjectId('68152a49d7982aac2b8fa1ce'), ObjectId('68152a49d7982aac2b8fa1cf'), ObjectId('68152a49d7982aac2b8fa1d0'), ObjectId('68152a49d7982aac2b8fa1d1'), ObjectId('68152a49d7982aac2b8fa1d2'), ObjectId('68152a49d7982aac2b8fa1d3'), ObjectId('68152a49d7982aac2b8fa1d4'), ObjectId('68152a49d7982aac2b8fa1d5'), ObjectId('68152a49d7982aac2b8fa1d6'), ObjectId('68152a49d7982aac2b8fa1d7'), ObjectId('68152a49d7982aac2b8fa1d8'), ObjectId('68152a49d7982aac2b8fa1d9'), ObjectId('68152a49d7982aac2b8fa1da'), ObjectId('68152a49d7982aac2b8fa1db'), ObjectId('68152a49d7982aac2b8fa1dc'), ObjectId('68152a49d7982aac2b8fa1dd'), ObjectId('68152a49d7982aac2b8fa1de'), ObjectId('68152a49d7982aac2b8fa1df'), ObjectId('68152a49d7982aac2b8fa1e0'), ObjectId('68152a49d7982aac2b8fa1e1'), ObjectId('68152a49d7982aac2b8fa1e2'), ObjectId('68152a49d7982aac2b8fa1e3'), ObjectId('68152a49d7982aac2b8fa1e4'), ObjectId('68152a49d7982aac2b8fa1e5'), ObjectId('68152a49d7982aac2b8fa1e6'), ObjectId('68152a49d7982aac2b8fa1e7'), ObjectId('68152a49d7982aac2b8fa1e8'), ObjectId('68152a49d7982aac2b8fa1e9'), ObjectId('68152a49d7982aac2b8fa1ea'), ObjectId('68152a49d7982aac2b8fa1eb'), ObjectId('68152a49d7982aac2b8fa1ec'), ObjectId('68152a49d7982aac2b8fa1ed'), ObjectId('68152a49d7982aac2b8fa1ee'), ObjectId('68152a49d7982aac2b8fa1ef'), ObjectId('68152a49d7982aac2b8fa1f0'), ObjectId('68152a49d7982aac2b8fa1f1'), ObjectId('68152a49d7982aac2b8fa1f2'), ObjectId('68152a49d7982aac2b8fa1f3'), ObjectId('68152a49d7982aac2b8fa1f4'), ObjectId('68152a49d7982aac2b8fa1f5'), ObjectId('68152a49d7982aac2b8fa1f6'), ObjectId('68152a49d7982aac2b8fa1f7'), ObjectId('68152a49d7982aac2b8fa1f8'), ObjectId('68152a49d7982aac2b8fa1f9'), ObjectId('68152a49d7982aac2b8fa1fa'), ObjectId('68152a49d7982aac2b8fa1fb'), ObjectId('68152a49d7982aac2b8fa1fc'), ObjectId('68152a49d7982aac2b8fa1fd'), ObjectId('68152a49d7982aac2b8fa1fe'), ObjectId('68152a49d7982aac2b8fa1ff'), ObjectId('68152a49d7982aac2b8fa200'), ObjectId('68152a49d7982aac2b8fa201'), ObjectId('68152a49d7982aac2b8fa202'), ObjectId('68152a49d7982aac2b8fa203'), ObjectId('68152a49d7982aac2b8fa204'), ObjectId('68152a49d7982aac2b8fa205'), ObjectId('68152a49d7982aac2b8fa206'), ObjectId('68152a49d7982aac2b8fa207'), ObjectId('68152a49d7982aac2b8fa208'), ObjectId('68152a49d7982aac2b8fa209'), ObjectId('68152a49d7982aac2b8fa20a'), ObjectId('68152a49d7982aac2b8fa20b'), ObjectId('68152a49d7982aac2b8fa20c'), ObjectId('68152a49d7982aac2b8fa20d'), ObjectId('68152a49d7982aac2b8fa20e'), ObjectId('68152a49d7982aac2b8fa20f'), ObjectId('68152a49d7982aac2b8fa210'), ObjectId('68152a49d7982aac2b8fa211'), ObjectId('68152a49d7982aac2b8fa212'), ObjectId('68152a49d7982aac2b8fa213'), ObjectId('68152a49d7982aac2b8fa214'), ObjectId('68152a49d7982aac2b8fa215'), ObjectId('68152a49d7982aac2b8fa216'), ObjectId('68152a49d7982aac2b8fa217'), ObjectId('68152a49d7982aac2b8fa218'), ObjectId('68152a49d7982aac2b8fa219'), ObjectId('68152a49d7982aac2b8fa21a')], acknowledged=True)

# %%
collection.count_documents({})
# Out:
# 96
